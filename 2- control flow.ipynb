# %% [markdown]
# Conditional Statements

# %%
#if statements
age = 23
if age>=18 :
    print("Eligible for voting!")
# Out:
# Eligible for voting!

# %%
age>=18
# Out:
# True

# %%
#else 
age=13
if age>=18 :
    print("Eligible for voting!")
else:
    print("Not Eligible for voting! you are minor ")
# Out:
# Not Eligible for voting! you are minor

# %%
#else if 
age=17 
if age<=13:
    print("you are a child")
elif age<=18:
    print("you are a teenager")
else:
    print("yor are an adult!")
# Out:
# you are a teenager

# %%
#nested conditional statements
#even, odd or negative 
num=int(input("enter a number: "))
if num>0:
    print("positive number")
    if num%2==0:
        print("even number")
    else:
        print("odd number")
else:
    print("number is zero or negative")
# Out:
# positive number
# odd number

# %%
#leap year nested if example

yr=int(input("enter the year: "))
if (yr%4==0):
    if yr%100==0:
        if yr%400==0:
            print( yr, "is a leap year")
        else:
            print("this year is not a leap year!")
    else:
        print(yr, " is a leap year")
else: 
    print(yr, "is not a leap year")
# Out:
# 2024  is a leap year

# %%
#Simple caluclator using elif 

a = float(input("1st number:  "))
b = float(input("2nd number:  "))
ch= input("enter operator (+, -, *, /)")

if ch== '+':
    result= a+b
elif ch== '-':
    result= a-b
elif ch== '*':
    result= a*b
elif ch== '/':
    if b!=0:
        result= a/b
    else:
        result = "error! Division by zero"
else:
    result= "invalied input"
print("result:", result)
# Out:
# result: error! Division by zero

# %%
#ticket pricing based on age and student status
#nested if
age= int(input("enter age: "))
std= input("are you a student? (y/n): ").lower()

if age <5:
    print("free")
elif age<=13:
    price ="$10"
