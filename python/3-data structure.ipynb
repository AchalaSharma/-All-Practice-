# %% [markdown]
# Lists:
#
# Lists are ordered and mutable collections of items.
#
# They can contain items of different data types.

# %%
list =[]
print(type('lst'))
# Out:
# <class 'str'>

# %%
names=["achala", "sharma", 1,2,3]
print(names)
# Out:
# ['achala', 'sharma', 1, 2, 3]

# %%
mixed_lst=['achala',0.12, True]
print(mixed_lst)
# Out:
# ['achala', 0.12, True]

# %%
#Accessinf list elements
fruits= ['apple','mango', 'papaya', 'kiwi']
fruits[1]
# Out:
# 'mango'
