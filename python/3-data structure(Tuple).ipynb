# %% [markdown]
# Tuples:
#
# Creating Tuples, Accessing Tuple Elements, Tuple Operations, Immutable Nature of Tuples, Tuple Methods, Packing and Unpacking Tuples,
# Nested Tuples
#
# Tuples are ordered collections of items that are immutable but immutability makes them different

# %%
#create
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple=(1,"Hello World",3.14, True)
print(mixed_tuple)
# Out:
# (1, 'Hello World', 3.14, True)

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[2])
print(numbers[-1])

numbers[0:4]
# Out:
# 3
# 6
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
#Tuple Operations
concatenation_tuple=numbers + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello World', 3.14, True)

# %%
mixed_tuple * 3
# Out:
# (1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True,
#  1,
#  'Hello World',
#  3.14,
#  True)

# %%
numbers *3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
#Immutable Nature Of Tuples

lst=[1,2,3,4,5]
print(lst)
lst[1]="Krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Krish', 3, 4, 5]

# %%
#Tuple Methods
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
# packing
packed_tuple=1,"Hello",3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
#unpacking
a,b,c=packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
# Unpacking with *
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
# Nested Tuple and Nested List
lst=[[1,2,3,4],[6,7,8,9],[1,"Hello",3.14,"c"]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello",3.14,"c")]
lst[2][0:3]
# Out:
# (1, 'Hello', 3.14)

# %%
nested_tuple = ((1, 2, 3), ("a", "b", "c"), (True, False))
## access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
# iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
